# %%
from SortingComparator import algorithms, compare_and_plot_algorithms
from itertools import combinations

# %%
algos = list(combinations(algorithms, 2))
for algo1, algo2 in reversed(algos):
    compare_and_plot_algorithms(algo1, algo2)
# Out:
# comparing `Random Pivot Quick Sort` vs `Median of 3 Pivot Quick Sort`
# ...............
# comparing `Merge Sort` vs `Median of 3 Pivot Quick Sort`
# ...............
# comparing `Merge Sort` vs `Random Pivot Quick Sort`
# ...............
# comparing `Insertion Sort` vs `Median of 3 Pivot Quick Sort`
# ...............
# comparing `Insertion Sort` vs `Random Pivot Quick Sort`
# ...............
# comparing `Insertion Sort` vs `Merge Sort`
# ...............
# comparing `Selection Sort` vs `Median of 3 Pivot Quick Sort`
# ...............
# comparing `Selection Sort` vs `Random Pivot Quick Sort`
# ...............
# comparing `Selection Sort` vs `Merge Sort`
# ...............
# comparing `Selection Sort` vs `Insertion Sort`
# ...............
# comparing `Bubble Sort` vs `Median of 3 Pivot Quick Sort`
# ...............
# comparing `Bubble Sort` vs `Random Pivot Quick Sort`
# ...............
# comparing `Bubble Sort` vs `Merge Sort`
# ...............
# comparing `Bubble Sort` vs `Insertion Sort`
# ...............
# comparing `Bubble Sort` vs `Selection Sort`
# ...............
