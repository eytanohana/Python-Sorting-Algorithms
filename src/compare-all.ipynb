# %%
from Sorting import *
from SortingComparator import *
from itertools import combinations

# %%
algos = list(combinations(algorithms, 2))
print(algos)
for algo1, algo2 in reversed(algos):
    compareAlgorithms(algo1, algo2)
# Out:
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
# ...............
